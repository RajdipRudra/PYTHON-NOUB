# %% [markdown]
# <h1  style='text-align:center';><i><b>Day 2</h1>
# <h5 style='text-align:center';><b>DATA TYPES,NUMBERS,OPERATIONS,TYPE CONVERSION,f-STRING</div>

# %% [markdown]
# <h5 style='text-align:center';><b>Data Types

# %% [markdown]
# <h4>Strings :</h4>
# <p>"Hello world" <- this's an example of string

# %%
#SUBScripting
print("Hello World"[0]) 
print("Hello World"[1]) 
print("Hello World"[3])
# Out:
# H
# e
# l

# %% [markdown]
# <h4>Integer :</h4>
# <p>12346776 <- this's an example of Integer{Whole number}

# %%
print(1236767)
# Out:
# 1236767

# %% [markdown]
# <h4>Float :</h4>
# <p>3.1416 <- this's an example of Floating point number

# %%
print(3.14159265359)
# Out:
# 3.14159265359

# %% [markdown]
# <h4>Boolean :</h4>
# <p>True and False <- this's an example of Boolean

# %%
if (3!=2) is True:
    print("67")
else:
    print("69")
# Out:
# 67

# %%
abul = 45
print(abul,type(abul))

abul = 6.7
print(abul,type(abul))

abul = 'Rudo'
print(abul,type(abul))

abul = False
print(abul,type(abul))
# Out:
# 45 <class 'int'>
# 6.7 <class 'float'>
# Rudo <class 'str'>
# False <class 'bool'>

# %%
print(70+float("100.5"))
# Out:
# 170.5

# %% [markdown]
# <h5 style='text-align:center';> <b>Code exercise 2.0

# %%
#easy and simple way ->

num = input("Type a tow difit number: ")
sum = int(num[0])+int(num[1])
print("your sum is -> ",sum)
# Out:
# your sum is ->  7

# %%
#Harder
# with a large amoutn of number

num = input("type a digit numbert: ")
sum = 0
for i in range(len(num)):
    sum+=int(num[i])
print(num)
print("your sum is -> ",sum)
# Out:
# 123456789101112131415
# your sum is ->  66

# %% [markdown]
# <h4 style='text-align:center';><b>Mathematical Operations :</h4>

# %%
3+5
7-4
3*2
6/3
2**10 #exponent or power
# Out:
# 1024

# %%
#Priorty -
'''
()
**
*,/
+,-

'''

print(3*3+3/3-3) #output should be 7
print(3*(3+3)/3-3)
# Out:
# 7.0
# 3.0

# %% [markdown]
# <h5 style='text-align:center';> <b>Code exercise 2.1

# %%
height = float(input("enter your height in m: "))
weight = float(input("enter your weight in kg: "))

BmI = weight/height**2
 
print("Your bim is ",round(BmI))
# Out:
# Your bim is  31.11

# %% [markdown]
# <h5 style='text-align:center';> <b>Code exercise 2.2

# %%
#LIFE IN WEEKS
age = int(input("What is your current age? "))

year_left = 90-age
months_left = year_left*12
weeks_left = year_left*52
days_left = year_left*365

print(f"You have {days_left} days, {weeks_left} weeks and {months_left} months left.")
# Out:
# You have 12410 days, 1768 weeks and 408 months left.
