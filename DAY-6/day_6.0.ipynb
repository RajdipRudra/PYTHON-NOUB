# %% [markdown]
# <h1  style='text-align:center';><i><b>Day 6</h1>
# <h5 style='text-align:center';><b>Functions, Code Blocks and While Loops</div>

# %% [markdown]
# <h5 style='text-align:center';><b>Functions

# %%
def my_function():
    print("Hello")
    print("Bye")

#we just defined the function here

# %%
my_function() # we are calling the function here
# Out:
# Hello
# Bye

# %%
import numpy as np
s = np.array([5,4,8,1,2])
d = np.sort(s)
print(d)
d = -np.sort(-s)
print(d)
# Out:
# [1 2 4 5 8]
# [8 5 4 2 1]

# %% [markdown]
# <h5 style='text-align:center';><b>While Loop

# %%
# while something_is_true:
#     #Do something repeatedly
def jump():
    print("JumP")
num_of_hurdels = 6
while num_of_hurdels>0:
    jump()
    num_of_hurdels-=1
# Out:
# JumP
# JumP
# JumP
# JumP
# JumP
# JumP

# %%
#Hurdel 4
''' 
def turn_right():
    turn_left()
    turn_left()
    turn_left()
def turn_around():
    turn_left()
    turn_left()

while at_goal()!= True:
    while wall_in_front()==True and wall_on_right()==True:
        turn_left()
    while wall_on_right()==True and wall_in_front()!=True:
        move()
    if right_is_clear()==True:
        turn_right()
        move()
    elif right_is_clear()==True:
        turn_right()

    elif front_is_clear()==True:
        move()
    
        




'''

# %%
#Maze

'''def turn_right():
    turn_left()
    turn_left()
    turn_left()
def turn_around():
    turn_left()
    turn_left()

while at_goal()!= True:
    while wall_in_front()==True and wall_on_right()==True and at_goal()!= True :
        turn_left()
    while wall_on_right()==True and wall_in_front()!=True and at_goal()!= True:
        move()
    if right_is_clear()==True and at_goal()!= True:
        turn_right()
        move()
    elif right_is_clear()==True and at_goal()!= True:
        turn_right()

    elif front_is_clear()==True and at_goal()!= True:
        move()
    
        



'''
# Out:
# 'def turn_right():\n    turn_left()\n    turn_left()\n    turn_left()\ndef turn_around():\n    turn_left()\n    turn_left()\n\nwhile at_goal()!= True:\n    while wall_in_front()==True and wall_on_right()==True and at_goal()!= True :\n        turn_left()\n    while wall_on_right()==True and wall_in_front()!=True and at_goal()!= True:\n        move()\n    if right_is_clear()==True and at_goal()!= True:\n        turn_right()\n        move()\n    elif right_is_clear()==True and at_goal()!= True:\n        turn_right()\n\n    elif front_is_clear()==True and at_goal()!= True:\n        move()\n\n\n\n\n\n'
