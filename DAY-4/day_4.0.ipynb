# %% [markdown]
# <h1  style='text-align:center';><i><b>Day 4</h1>
# <h5 style='text-align:center';><b>Randomisation and Python Lists</div>

# %% [markdown]
# <h5 style='text-align:center';><b>Randomisation

# %%
import random as rn
#we'r gonna gen random integers from the range 1-50
random_int = rn.randint(0,5)
print(random_int)

random_float = rn.random()
print(random_float*5)
# Out:
# 4
# 2.9213184319816032

# %% [markdown]
# <h4>Understanding modules

# %%
import module as mo

print(f"the value of pi is {mo.PI}")
# Out:
# the value of pi is 3.14159

# %%
sum_result = mo.add_numbers(67,69)
meter_cm = mo.meters_to_cm(200)
print("sum = ",sum_result)
print("meter to cm is",meter_cm)
print("".join(mo.get_first_letter(["Raj","dev","Luffy","sukuna","Joy"])))
# Out:
# sum =  136
# meter to cm is 20000
# RdLsJ

# %%
print("Welcome to the Love Calculator!")
name1 = input("What is your name? \n").lower()#rajdip rudra
name2 = input("What is their Name?").lower()#ajme islam prionty

love_sum = rn.randint(1,100)

if int(love_sum)<=10 or int(love_sum)>=90:
    print(f"Your Love score is {love_sum}%, you go together like coke and mentos")
elif int(love_sum)>=40 and int(love_sum)<=50:
    print(f"Your Love score is {love_sum}%, You guy's r okey together")
else:
    print(f"Your Love score is {love_sum}")
# Out:
# Welcome to the Love Calculator!
# Your Love score is 13

# %%
#easy
for i in range(10):
    resut = rn.choice(["Head","Tail"])
    print(resut)
# Out:
# Tail
# Tail
# Tail
# Head
# Tail
# Tail
# Tail
# Head
# Tail
# Head

# %%
#Hard
Test_seed = int(input("Creat a seed number: "))
rn.seed(Test_seed)
Test = rn.randint(1,100)
if Test_seed%2==0:
    print("Head")
else:
    print("Tails")
# Out:
# Head

# %% [markdown]
# <h5 style='text-align:center';><b>Lists

# %%
usa_states_by_admission = [
    "Delaware",
    "Pennsylvania",
    "New Jersey",
    "Georgia",
    "Connecticut",
    "Massachusetts",
    "Maryland",
    "South Carolina",
    "New Hampshire",
    "Virginia",
    "New York",
    "North Carolina",
    "Rhode Island",
    "Vermont",
    "Kentucky",
    "Tennessee",
    "Ohio",
    "Louisiana",
    "Indiana",
    "Mississippi",
    "Illinois",
    "Alabama",
    "Maine",
    "Missouri",
    "Arkansas",
    "Michigan",
    "Florida",
    "Texas",
    "Iowa",
    "Wisconsin",
    "California",
    "Minnesota",
    "Oregon",
    "Kansas",
    "West Virginia",
    "Nevada",
    "Nebraska",
    "Colorado",
    "North Dakota",
    "South Dakota",
    "Montana",
    "Washington",
    "Idaho",
    "Wyoming",
    "Utah",
    "Oklahoma",
    "New Mexico",
    "Arizona",
    "Alaska",
    "Hawaii"
]
print(usa_states_by_admission[0])
print(usa_states_by_admission[4])
print(usa_states_by_admission[-1])
print(usa_states_by_admission[-4])
print(usa_states_by_admission)
# Out:
# Delaware
# Connecticut
# Hawaii
# New Mexico
# ['Delaware', 'Pennsylvania', 'New Jersey', 'Georgia', 'Connecticut', 'Massachusetts', 'Maryland', 'South Carolina', 'New Hampshire', 'Virginia', 'New York', 'North Carolina', 'Rhode Island', 'Vermont', 'Kentucky', 'Tennessee', 'Ohio', 'Louisiana', 'Indiana', 'Mississippi', 'Illinois', 'Alabama', 'Maine', 'Missouri', 'Arkansas', 'Michigan', 'Florida', 'Texas', 'Iowa', 'Wisconsin', 'California', 'Minnesota', 'Oregon', 'Kansas', 'West Virginia', 'Nevada', 'Nebraska', 'Colorado', 'North Dakota', 'South Dakota', 'Montana', 'Washington', 'Idaho', 'Wyoming', 'Utah', 'Oklahoma', 'New Mexico', 'Arizona', 'Alaska', 'Hawaii']

# %%
print(f"before modifing = {usa_states_by_admission[1]}")
usa_states_by_admission[1] = "Republic of pencile"
print("after modifing = ",usa_states_by_admission[1])
# Out:
# before modifing = Pennsylvania
# after modifing =  Republic of pencile

# %%
#adding a new element on list
usa_states_by_admission.append("Republic of Rudra")
print(usa_states_by_admission[30:])
# Out:
# ['California', 'Minnesota', 'Oregon', 'Kansas', 'West Virginia', 'Nevada', 'Nebraska', 'Colorado', 'North Dakota', 'South Dakota', 'Montana', 'Washington', 'Idaho', 'Wyoming', 'Utah', 'Oklahoma', 'New Mexico', 'Arizona', 'Alaska', 'Hawaii', 'Republic of Rudra']

# %%
#Extending the list with multiple elements
usa_states_by_admission.extend(["Rajland","JoyLand","La La Land","Thailand", "Finland", "Iceland", "Norway", "Poland"])

# %%
print(usa_states_by_admission[40:])
# Out:
# ['Montana', 'Washington', 'Idaho', 'Wyoming', 'Utah', 'Oklahoma', 'New Mexico', 'Arizona', 'Alaska', 'Hawaii', 'Republic of Rudra', 'Rajland', 'JoyLand', 'La La Land', 'Thailand', 'Finland', 'Iceland', 'Norway', 'Poland']

# %%
#Inserting something into a list by it's index number and the value
usa_states_by_admission.insert(round(len(usa_states_by_admission)/2),"NoMan's Land")
print(usa_states_by_admission[round(len(usa_states_by_admission)/2):])
# Out:
# ["NoMan's Land", 'California', 'Minnesota', 'Oregon', 'Kansas', 'West Virginia', 'Nevada', 'Nebraska', 'Colorado', 'North Dakota', 'South Dakota', 'Montana', 'Washington', 'Idaho', 'Wyoming', 'Utah', 'Oklahoma', 'New Mexico', 'Arizona', 'Alaska', 'Hawaii', 'Republic of Rudra', 'Rajland', 'JoyLand', 'La La Land', 'Thailand', 'Finland', 'Iceland', 'Norway', 'Poland']

# %%
for i in range(len(usa_states_by_admission)):
    print(f"{usa_states_by_admission[i]} = {i}\n")
# Out:
# Delaware = 0
#
# Republic of pencile = 1
#
# New Jersey = 2
#
# Georgia = 3
#
# Connecticut = 4
#
# Massachusetts = 5
#
# Maryland = 6
#
# South Carolina = 7
#
# New Hampshire = 8
#
# Virginia = 9
#
# New York = 10
#
# North Carolina = 11
#
# Rhode Island = 12
#
# Vermont = 13
#
# Kentucky = 14
#
# Tennessee = 15
#
# Ohio = 16
#
# Louisiana = 17
#
# Indiana = 18
#
# Mississippi = 19
#
# Illinois = 20
#
# Alabama = 21
#
# Maine = 22
#
# Missouri = 23
#
# Arkansas = 24
#
# Michigan = 25
#
# Florida = 26
#
# Texas = 27
#
# Iowa = 28
#
# Wisconsin = 29
#
# NoMan's Land = 30
#
# California = 31
#
# Minnesota = 32
#
# Oregon = 33
#
# Kansas = 34
#
# West Virginia = 35
#
# Nevada = 36
#
# Nebraska = 37
#
# Colorado = 38
#
# North Dakota = 39
#
# South Dakota = 40
#
# Montana = 41
#
# Washington = 42
#
# Idaho = 43
#
# Wyoming = 44
#
# Utah = 45
#
# Oklahoma = 46
#
# New Mexico = 47
#
# Arizona = 48
#
# Alaska = 49
#
# Hawaii = 50
#
# Republic of Rudra = 51
#
# Rajland = 52
#
# JoyLand = 53
# ...

# %%
#list.remove(value, /)
#Remove the first item from the list whose value is equal to value. It raises a ValueError if there is no such item.

usa_states_by_admission.remove("Thailand")

for i in range(len(usa_states_by_admission)):
    print(f"{usa_states_by_admission[i]} = {i}\n")
# Out:
# Delaware = 0
#
# Republic of pencile = 1
#
# New Jersey = 2
#
# Georgia = 3
#
# Connecticut = 4
#
# Massachusetts = 5
#
# Maryland = 6
#
# South Carolina = 7
#
# New Hampshire = 8
#
# Virginia = 9
#
# New York = 10
#
# North Carolina = 11
#
# Rhode Island = 12
#
# Vermont = 13
#
# Kentucky = 14
#
# Tennessee = 15
#
# Ohio = 16
#
# Louisiana = 17
#
# Indiana = 18
#
# Mississippi = 19
#
# Illinois = 20
#
# Alabama = 21
#
# Maine = 22
#
# Missouri = 23
#
# Arkansas = 24
#
# Michigan = 25
#
# Florida = 26
#
# Texas = 27
#
# Iowa = 28
#
# Wisconsin = 29
#
# NoMan's Land = 30
#
# California = 31
#
# Minnesota = 32
#
# Oregon = 33
#
# Kansas = 34
#
# West Virginia = 35
#
# Nevada = 36
#
# Nebraska = 37
#
# Colorado = 38
#
# North Dakota = 39
#
# South Dakota = 40
#
# Montana = 41
#
# Washington = 42
#
# Idaho = 43
#
# Wyoming = 44
#
# Utah = 45
#
# Oklahoma = 46
#
# New Mexico = 47
#
# Arizona = 48
#
# Alaska = 49
#
# Hawaii = 50
#
# Republic of Rudra = 51
#
# Rajland = 52
#
# JoyLand = 53
# ...

# %%
##To count how manny time the same element is in a list
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']
print(fruits.count('apple'))

print(fruits.count('tangerine'))
# Out:
# 2
# 0

# %%
print(fruits.index('banana'))

print(fruits.index('banana', 4))  # Find next banana starting at position 4
# Out:
# 3
# 6

# %%
fruits.reverse()
fruits
# Out:
# ['banana', 'apple', 'kiwi', 'banana', 'pear', 'apple', 'orange']

# %%
fruits.sort()
fruits
# Out:
# ['apple', 'apple', 'banana', 'banana', 'kiwi', 'orange', 'pear']

# %% [markdown]
# <h5 style='text-align:center';><b>Code excecise 4.0</h5>
# <p style='text-align:center';>Who's paying?

# %%
import random as rn
test_seed = int(input("Create a seed Number: "))
rn.seed(test_seed)

nameAsCSV = input("Give me everybody's names, separated by comma\n")
names = nameAsCSV.split(",")

#technique one:
The_person_is = rn.choice(names)
print(f"{The_person_is} is going to buy the meal today!")
# Out:
#  khairul is going to buy the meal today!

# %%
#technique two:

random_intg = rn.randint(1,len(names))
print(f"{names[random_intg-1]} is going to buy the meal today!")
# Out:
# raj is going to buy the meal today!

# %%
vegetables = ["Spinach","Kale","Tomatoes","Celery","Potatoes"]
fruits = ["Straqberries","Nectarines","Apples","Grapes","Peaches","Cherries","Pears"]

dirty_dozen = [vegetables,fruits]
dirty_dozen
# Out:
# [['Spinach', 'Kale', 'Tomatoes', 'Celery', 'Potatoes'],
#  ['Straqberries',
#   'Nectarines',
#   'Apples',
#   'Grapes',
#   'Peaches',
#   'Cherries',
#   'Pears']]

# %%
print(dirty_dozen[0][-1])
print(dirty_dozen[1][0])
# Out:
# Potatoes
# Straqberries

# %%
import os
row1 = ['⬜️', '⬜️', '⬜️']
row2 = ['⬜️', '⬜️', '⬜️']
row3 = ['⬜️', '⬜️', '⬜️']

map =[row1,row2,row3]
print(f"{row1}\n{row2}\n{row3}\n")

position = input("Where do you want to put the Treasure?{first column then row} ") # 23 2 is the column and 3 is the row
row = int(position[1])-1
colum = int(position[0])-1
map[row][colum] = "💰"





print(f"{row1}\n{row2}\n{row3}\n")
# Out:
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
#
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '💰', '⬜️']

# %% [markdown]
# <h5><b>

# %%
rock = r'''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''

paper = r'''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''

scissors = r'''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''

asciisss = [rock,paper,scissors]

vs_art = r"""
\   /  ___ 
 \ /  /__  
  V   ___/ 
"""



logo = fr''' 
  _____            _           _____                             _____      _                    
 |  __ \          | |         |  __ \                           / ____|    (_)                   
 | |__) |___   ___| | ________| |__) |_ _ _ __   ___ _ __ _____| (___   ___ _ ___ ___  ___  _ __ 
 |  _  // _ \ / __| |/ /______|  ___/ _` | '_ \ / _ \ '__|______\___ \ / __| / __/ __|/ _ \| '__|
 | | \ \ (_) | (__|   <       | |  | (_| | |_) |  __/ |         ____) | (__| \__ \__ \ (_) | |   
 |_|  \_\___/ \___|_|\_\      |_|   \__,_| .__/ \___|_|        |_____/ \___|_|___/___/\___/|_|   
                                         | |                                                     
                                         |_|                                                     
'''


import random as rn
print(logo)
asciii = [rock,paper,scissors]
user_input = int(input("Enter 0 for Rock, 1 for Paper, 2 for Scissor"))
computer_input = rn.randint(0,2)


print(f"Your Choise:\n{asciisss[user_input]}")
print(vs_art)
print(f"\nComputer's Choise:\n{asciisss[computer_input]}")

if user_input==computer_input:
    print("IT's A TIE.")

elif (user_input==0 and computer_input==2) or (user_input==2 and computer_input==1) or (user_input==2 and computer_input==0):
    print("YOU WIN!!")

elif (computer_input==0 and user_input==2) or (computer_input==2 and user_input==1) or (computer_input==2 and user_input==0):
    print("YOU LOST, try again")
# Out:
#
#   _____            _           _____                             _____      _
#  |  __ \          | |         |  __ \                           / ____|    (_)
#  | |__) |___   ___| | ________| |__) |_ _ _ __   ___ _ __ _____| (___   ___ _ ___ ___  ___  _ __
#  |  _  // _ \ / __| |/ /______|  ___/ _` | '_ \ / _ \ '__|______\___ \ / __| / __/ __|/ _ \| '__|
#  | | \ \ (_) | (__|   <       | |  | (_| | |_) |  __/ |         ____) | (__| \__ \__ \ (_) | |
#  |_|  \_\___/ \___|_|\_\      |_|   \__,_| .__/ \___|_|        |_____/ \___|_|___/___/\___/|_|
#                                          | |
#                                          |_|
#
# Your Choise:
#
#     _______
# ---'   ____)____
#           ______)
#        __________)
#       (____)
# ---.__(___)
#
#
# \   /  ___
#  \ /  /__
#   V   ___/
#
#
#
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
# Computer's Choise:
