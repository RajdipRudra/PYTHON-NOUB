# %% [markdown]
# <h1  style='text-align:center';><i><b>Day 7</h1>
# <h5 style='text-align:center';><b>HangMan Project</div>

# %%
import random as rn
from hangman_word import WOrdS,words_hints
import hangman_art
# Out:
# ['apple', 'banana', 'orange', 'grapes', 'mango', 'peach', 'cherry', 'melon', 'papaya', 'guava', 'lemon', 'lime', 'coconut', 'avocado', 'carrot', 'potato', 'tomato', 'onion', 'garlic', 'pepper', 'broccoli', 'spinach', 'cabbage', 'pumpkin', 'radish', 'school', 'college', 'teacher', 'student', 'library', 'notebook', 'pencil', 'eraser', 'science', 'history', 'physics', 'biology', 'chemistry', 'algebra', 'python', 'javascript', 'compiler', 'keyboard', 'monitor', 'internet', 'website', 'browser', 'database', 'network', 'server', 'gaming', 'console', 'controller', 'adventure', 'puzzle', 'strategy', 'football', 'cricket', 'tennis', 'badminton', 'hockey', 'volleyball', 'basketball', 'captain', 'stadium', 'journey', 'holiday', 'airport', 'station', 'highway', 'village', 'country', 'mountain', 'desert', 'forest', 'ocean', 'island', 'planet', 'galaxy', 'comet', 'rocket', 'astronaut', 'sunrise', 'sunset', 'thunder', 'rainfall', 'weather', 'winter', 'summer', 'autumn', 'spring', 'friend', 'family', 'brother', 'sister', 'father', 'mother', 'uncle', 'aunt', 'cousin', 'garden', 'flower', 'butterfly', 'diamond', 'crystal', 'treasure', 'shadow', 'mirror', 'blanket', 'window', 'curtain', 'pillow', 'kitchen', 'bedroom', 'balcony', 'freedom', 'justice', 'wisdom', 'honesty', 'courage', 'respect', 'silence', 'passion', 'dream', 'future', 'success', 'failure', 'victory', 'mystery', 'monster', 'dragon', 'wizard', 'knight', 'castle', 'kingdom', 'legend', 'ancient', 'pirate', 'ninja', 'samurai', 'hunter', 'warrior', 'machine', 'factory', 'battery', 'engine', 'vehicle', 'bicycle', 'airplane', 'submarine', 'camera', 'speaker', 'headphone', 'backpack', 'wallet', 'ticket', 'festival', 'concert']
# {'apple': 'A common red or green fruit', 'banana': 'A long yellow fruit', 'orange': 'A citrus fruit and a color', 'grapes': 'Small fruits used to make wine', 'mango': 'A tropical sweet fruit', 'peach': 'A soft fruit with fuzzy skin', 'cherry': 'A small red fruit with a seed', 'melon': 'A large juicy fruit', 'papaya': 'A tropical fruit with orange flesh', 'guava': 'A tropical fruit rich in vitamin C', 'lemon': 'A sour yellow citrus fruit', 'lime': 'A small green citrus fruit', 'coconut': 'A hard tropical fruit with water inside', 'avocado': 'A creamy green fruit', 'carrot': 'An orange root vegetable', 'potato': 'A starchy vegetable grown underground', 'tomato': 'A red fruit often used as a vegetable', 'onion': 'A vegetable that can make you cry', 'garlic': 'A strong-smelling cooking ingredient', 'pepper': 'A spicy vegetable or seasoning', 'broccoli': 'A green vegetable shaped like a tree', 'spinach': 'A leafy green vegetable', 'cabbage': 'A round leafy vegetable', 'pumpkin': 'A large orange vegetable used on Halloween', 'radish': 'A small spicy root vegetable', 'school': 'A place where students learn', 'college': 'A place for higher education', 'teacher': 'A person who educates students', 'student': 'A person who studies', 'library': 'A place full of books', 'notebook': 'Used for writing notes', 'pencil': 'A tool used for writing', 'eraser': 'Used to remove pencil marks', 'science': 'The study of the natural world', 'history': 'The study of past events', 'physics': 'The science of matter and energy', 'biology': 'The study of living organisms', 'chemistry': 'The science of substances and reactions', 'algebra': 'A branch of mathematics', 'python': 'A popular programming language', 'javascript': 'A language used for web development', 'compiler': 'Turns code into executable programs', 'keyboard': 'Used to type on a computer', 'monitor': 'Displays images from a computer', 'internet': 'A worldwide network connection', 'website': 'A collection of web pages', 'browser': 'Used to access websites', 'database': 'Stores organized information', 'network': 'Connected systems or computers', 'server': 'Provides data to other computers', 'gaming': 'Playing video games', 'console': 'A device used for gaming', 'controller': 'Used to control games', 'adventure': 'An exciting experience or journey', 'puzzle': 'A game that tests thinking', 'strategy': 'A plan to achieve success', 'football': 'A popular team sport', 'cricket': 'A bat-and-ball sport', 'tennis': 'A racket sport', 'badminton': 'A sport played with a shuttlecock', 'hockey': 'A sport played with sticks', 'volleyball': 'A sport played over a net', 'basketball': 'A sport involving hoops', 'captain': 'The leader of a team', 'stadium': 'A large sports venue', 'journey': 'Travel from one place to another', 'holiday': 'A period of vacation', 'airport': 'Where airplanes take off and land', 'station': 'A place where trains or buses stop', 'highway': 'A major road', 'village': 'A small rural settlement', 'country': 'A nation with its own government', 'mountain': 'A very high natural landform', 'desert': 'A dry sandy region', 'forest': 'A large area full of trees', 'ocean': 'A vast body of salt water', 'island': 'Land surrounded by water', 'planet': 'A large object orbiting a star', 'galaxy': 'A system of millions of stars', 'comet': 'An icy object in space', 'rocket': 'Used for space travel', 'astronaut': 'A person trained for space missions', 'sunrise': 'The start of the day', 'sunset': 'The end of the day', 'thunder': 'The sound during a storm', 'rainfall': 'Rain coming from clouds', 'weather': 'Atmospheric conditions outside', 'winter': 'The coldest season', 'summer': 'The hottest season', 'autumn': 'The season when leaves fall', 'spring': 'The season of blooming flowers', 'friend': 'Someone close to you', 'family': 'People related to you', 'brother': 'A male sibling', 'sister': 'A female sibling', 'father': 'A male parent', 'mother': 'A female parent', 'uncle': "A parent's brother", 'aunt': "A ...

# %%
print(hangman_art.logo)
# Out:
#
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/

# %%
GenWord = rn.choice(WOrdS).lower()
Hint = words_hints[GenWord]
HangStage = hangman_art.stages
LifeLine = len(HangStage)-1

print(GenWord)
print(Hint)
# Out:
# diamond
# A precious gemstone

# %%
def dash(word):
    word_list = []
    for i in word:
        word_list.append(" _")
    return word_list

dash(GenWord)
# Out:
# [' _', ' _', ' _', ' _', ' _', ' _', ' _']

# %%
def dashReplace(dash,word,user_input):
    for j in range(len(word)):
        if word[j]==user_input:
            dash[j] = user_input
    return dash

# %%
is_gameon = LifeLine
Dashe = dash(GenWord)
while is_gameon >= 0:
    
    print("".join(Dashe))
    user_input = input("Guess a letter").lower()
    if user_input in GenWord:
        Dashe = dashReplace(Dashe,GenWord,user_input)
    else:
        is_gameon-= 1
        print(HangStage[is_gameon])
# Out:
# A precious gemstone
#
#  _ _ _ _ _ _ _
# A precious gemstone
#
# d _ _ _ _ _d
# A precious gemstone
#
# d _ _ _o _d
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
#
# A precious gemstone
#
# d _ _ _o _d
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# A precious gemstone
#
# d _ _ _o _d
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
#
# A precious gemstone
#
# d _ _ _o _d
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# A precious gemstone
#
# d _ _ _o _d
# A precious gemstone
#
# di _ _o _d
# A precious gemstone
#
# di _mo _d
# A precious gemstone
#
# di _mond
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# =========
#
# A precious gemstone
#
# di _mond
# A precious gemstone
#
# diamond
